# %%
import config
import sys
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(config.client_id, config.client_secret))

# %%
my_user_id = config.my_user

# %%
playlists = sp.user_playlists(my_user_id)['items']

# %%
playlist_ids = [p['id'] for p in playlists]

# %%
sp.playlist_tracks(playlist_ids[0])['items']
# Out:
# [{'added_at': '2020-02-19T19:12:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#       'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#       'id': '5INjqkS1o8h1imAzPqGZBb',
#       'name': 'Tame Impala',
#       'type': 'artist',
#       'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6KJKA9j7EE8xlpizKGGjvE'},
#     'href': 'https://api.spotify.com/v1/albums/6KJKA9j7EE8xlpizKGGjvE',
#     'id': '6KJKA9j7EE8xlpizKGGjvE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/059e2a914cc50ce0b5965851cd268feb56d33ab3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6e973dfd421b7429703b1cb246f8b81d25b117d5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/42988173e01435e86d843a175ce7839204e592a1',
#       'width': 64}],
#     'name': 'Lost In Yesterday',
#     'release_date': '2020-01-08',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6KJKA9j7EE8xlpizKGGjvE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#      'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#      'id': '5INjqkS1o8h1imAzPqGZBb',
#      'name': 'Tame Impala',
#      'type': 'artist',
#      'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 249586,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUUM71900932'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3eoNUm0LU9hATVVi9w4fM6'},
#    'href': 'https://api.spotify.com/v1/tracks/3eoNUm0LU9hATVVi9w4fM6',
#    'id': '3eoNUm0LU9hATVVi9w4fM6',
#    'is_local': False,
#    'name': 'Lost In Yesterday',
#    'popularity': 77,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3eoNUm0LU9hATVVi9w4fM6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:12:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cIc3SBFuBLVxJz58W2tU9'},
#       'href': 'https://api.spotify.com/v1/artists/5cIc3SBFuBLVxJz58W2tU9',
#       'id': '5cIc3SBFuBLVxJz58W2tU9',
#       'name': 'Oh Wonder',
#       'type': 'artist',
#       'uri': 'spotify:artist:5cIc3SBFuBLVxJz58W2tU9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5WcnEz9vhNjIlIu0sv0hJZ'},
#     'href': 'https://api.spotify.com/v1/albums/5WcnEz9vhNjIlIu0sv0hJZ',
#     'id': '5WcnEz9vhNjIlIu0sv0hJZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5921d274a3e50a8c5dabb9fcb67177233c59ffdc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/91b259442c23ad1c3ae4ab8965ee0b1eb92131f2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ca4508205ab9675cc7774099977b81074d4aee51',
#       'width': 64}],
#     'name': 'Happy',
#     'release_date': '2020-01-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5WcnEz9vhNjIlIu0sv0hJZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cIc3SBFuBLVxJz58W2tU9'},
#      'href': 'https://api.spotify.com/v1/artists/5cIc3SBFuBLVxJz58W2tU9',
#      'id': '5cIc3SBFuBLVxJz58W2tU9',
#      'name': 'Oh Wonder',
#      'type': 'artist',
#      'uri': 'spotify:artist:5cIc3SBFuBLVxJz58W2tU9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 172906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71905532'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7oIAqDzsqgVpUaMXuultdC'},
#    'href': 'https://api.spotify.com/v1/tracks/7oIAqDzsqgVpUaMXuultdC',
#    'id': '7oIAqDzsqgVpUaMXuultdC',
#    'is_local': False,
#    'name': 'Happy',
#    'popularity': 67,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7oIAqDzsqgVpUaMXuultdC'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:13:14Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#       'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#       'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#       'name': 'Selena Gomez',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3YPFaTR7WMi1Hd4NVKdCJx'},
#     'href': 'https://api.spotify.com/v1/albums/3YPFaTR7WMi1Hd4NVKdCJx',
#     'id': '3YPFaTR7WMi1Hd4NVKdCJx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/977888b6bdd3d19effd2e26ad5714f32257ecc78',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/af9227d9f9a0da062616500d3c490409b7ce82c6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/9e9665086a76d832884538457c98170be3cdb205',
#       'width': 64}],
#     'name': 'Rare',
#     'release_date': '2020-01-10',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:3YPFaTR7WMi1Hd4NVKdCJx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#      'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#      'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#      'name': 'Selena Gomez',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 206458,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71918727'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4l0Mvzj72xxOpRrp6h8nHi'},
#    'href': 'https://api.spotify.com/v1/tracks/4l0Mvzj72xxOpRrp6h8nHi',
#    'id': '4l0Mvzj72xxOpRrp6h8nHi',
#    'is_local': False,
#    'name': 'Lose You To Love Me',
#    'popularity': 91,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4l0Mvzj72xxOpRrp6h8nHi'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:14:08Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63iWSELt9V1kV6RSMxN7Ii'},
#     'href': 'https://api.spotify.com/v1/albums/63iWSELt9V1kV6RSMxN7Ii',
#     'id': '63iWSELt9V1kV6RSMxN7Ii',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737fe4a82a08c4f0decbeddbc6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027fe4a82a08c4f0decbeddbc6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517fe4a82a08c4f0decbeddbc6',
#       'width': 64}],
#     'name': 'Changes',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:63iWSELt9V1kV6RSMxN7Ii'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yy76ufVriyvidNSvXlRU1'},
#      'href': 'https://api.spotify.com/v1/artists/5yy76ufVriyvidNSvXlRU1',
#      'id': '5yy76ufVriyvidNSvXlRU1',
#      'name': 'Clever',
#      'type': 'artist',
#      'uri': 'spotify:artist:5yy76ufVriyvidNSvXlRU1'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 219933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72001323'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ZlCGeK30BLRNSPC832pNZ'},
#    'href': 'https://api.spotify.com/v1/tracks/2ZlCGeK30BLRNSPC832pNZ',
#    'id': '2ZlCGeK30BLRNSPC832pNZ',
#    'is_local': False,
#    'name': 'Forever (feat. Post Malone & Clever)',
#    'popularity': 84,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:2ZlCGeK30BLRNSPC832pNZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:14:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63iWSELt9V1kV6RSMxN7Ii'},
#     'href': 'https://api.spotify.com/v1/albums/63iWSELt9V1kV6RSMxN7Ii',
#     'id': '63iWSELt9V1kV6RSMxN7Ii',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737fe4a82a08c4f0decbeddbc6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027fe4a82a08c4f0decbeddbc6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517fe4a82a08c4f0decbeddbc6',
#       'width': 64}],
#     'name': 'Changes',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:63iWSELt9V1kV6RSMxN7Ii'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VRj0yCOv2FXJNP47XQnx5'},
#      'href': 'https://api.spotify.com/v1/artists/0VRj0yCOv2FXJNP47XQnx5',
#      'id': '0VRj0yCOv2FXJNP47XQnx5',
#      'name': 'Quavo',
#      'type': 'artist',
#      'uri': 'spotify:artist:0VRj0yCOv2FXJNP47XQnx5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 212866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72001302'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4umIPjkehX1r7uhmGvXiSV'},
#    'href': 'https://api.spotify.com/v1/tracks/4umIPjkehX1r7uhmGvXiSV',
#    'id': '4umIPjkehX1r7uhmGvXiSV',
#    'is_local': False,
#    'name': 'Intentions (feat. Quavo)',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4umIPjkehX1r7uhmGvXiSV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:17:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anyVhU62p31KFi8MEzkbf'},
#       'href': 'https://api.spotify.com/v1/artists/1anyVhU62p31KFi8MEzkbf',
#       'id': '1anyVhU62p31KFi8MEzkbf',
#       'name': 'Chance the Rapper',
#       'type': 'artist',
#       'uri': 'spotify:artist:1anyVhU62p31KFi8MEzkbf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7niOG7nbuUzXSvNtJruogj'},
#     'href': 'https://api.spotify.com/v1/albums/7niOG7nbuUzXSvNtJruogj',
#     'id': '7niOG7nbuUzXSvNtJruogj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a29ab3b0e07c6191f7d3ca6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a29ab3b0e07c6191f7d3ca6b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a29ab3b0e07c6191f7d3ca6b',
#       'width': 64}],
#     'name': 'The Big Day',
#     'release_date': '2019-07-26',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:7niOG7nbuUzXSvNtJruogj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anyVhU62p31KFi8MEzkbf'},
#      'href': 'https://api.spotify.com/v1/artists/1anyVhU62p31KFi8MEzkbf',
#      'id': '1anyVhU62p31KFi8MEzkbf',
#      'name': 'Chance the Rapper',
#      'type': 'artist',
#      'uri': 'spotify:artist:1anyVhU62p31KFi8MEzkbf'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 299167,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMEZE1949299'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7yyctNHay8NO1VwCv7LDP3'},
#    'href': 'https://api.spotify.com/v1/tracks/7yyctNHay8NO1VwCv7LDP3',
#    'id': '7yyctNHay8NO1VwCv7LDP3',
#    'is_local': False,
#    'name': 'We Go High',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2e1faac9422167c197bdc18e920f70fc10396e4d?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7yyctNHay8NO1VwCv7LDP3'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:18:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LLpKhyESsyAXpc4laK94U'},
#       'href': 'https://api.spotify.com/v1/artists/4LLpKhyESsyAXpc4laK94U',
#       'id': '4LLpKhyESsyAXpc4laK94U',
#       'name': 'Mac Miller',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LLpKhyESsyAXpc4laK94U'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5sY6UIQ32GqwMLAfSNEaXb'},
#     'href': 'https://api.spotify.com/v1/albums/5sY6UIQ32GqwMLAfSNEaXb',
#     'id': '5sY6UIQ32GqwMLAfSNEaXb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/bb2ef71c9576794699222ef73a00a0a1a8ddd3db',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f936b1c322bcb20189b8ae752d78087a68bb0145',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/49fff681c4862575dd7f1ee3b5b473404d2f1506',
#       'width': 64}],
#     'name': 'Circles',
#     'release_date': '2020-01-17',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5sY6UIQ32GqwMLAfSNEaXb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LLpKhyESsyAXpc4laK94U'},
#      'href': 'https://api.spotify.com/v1/artists/4LLpKhyESsyAXpc4laK94U',
#      'id': '4LLpKhyESsyAXpc4laK94U',
#      'name': 'Mac Miller',
#      'type': 'artist',
#      'uri': 'spotify:artist:4LLpKhyESsyAXpc4laK94U'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 298440,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB11801014'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Yv2mHzr5AQavVdwQjEokV'},
#    'href': 'https://api.spotify.com/v1/tracks/2Yv2mHzr5AQavVdwQjEokV',
#    'id': '2Yv2mHzr5AQavVdwQjEokV',
#    'is_local': False,
#    'name': 'Hand Me Downs',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/91d443cf46b9574e40dad9306625958ee5d2357d?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:2Yv2mHzr5AQavVdwQjEokV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:20:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#       'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#       'id': '5INjqkS1o8h1imAzPqGZBb',
#       'name': 'Tame Impala',
#       'type': 'artist',
#       'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/31qVWUdRrlb8thMvts0yYL'},
#     'href': 'https://api.spotify.com/v1/albums/31qVWUdRrlb8thMvts0yYL',
#     'id': '31qVWUdRrlb8thMvts0yYL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27358267bd34420a00d5cf83a49',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0258267bd34420a00d5cf83a49',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485158267bd34420a00d5cf83a49',
#       'width': 64}],
#     'name': 'The Slow Rush',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:31qVWUdRrlb8thMvts0yYL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#      'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#      'id': '5INjqkS1o8h1imAzPqGZBb',
#      'name': 'Tame Impala',
#      'type': 'artist',
#      'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 372866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUUM71900929'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3LbZIhU0smEU5SUnxod4j4'},
#    'href': 'https://api.spotify.com/v1/tracks/3LbZIhU0smEU5SUnxod4j4',
#    'id': '3LbZIhU0smEU5SUnxod4j4',
#    'is_local': False,
#    'name': 'Breathe Deeper',
#    'popularity': 75,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:3LbZIhU0smEU5SUnxod4j4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:21:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uRxRKC7d9zwYGSRflTKDR'},
#       'href': 'https://api.spotify.com/v1/artists/1uRxRKC7d9zwYGSRflTKDR',
#       'id': '1uRxRKC7d9zwYGSRflTKDR',
#       'name': 'SAULT',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uRxRKC7d9zwYGSRflTKDR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/19uWOx2aMKl7cdesfEyFms'},
#     'href': 'https://api.spotify.com/v1/albums/19uWOx2aMKl7cdesfEyFms',
#     'id': '19uWOx2aMKl7cdesfEyFms',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9c22fdd0f23fc95ddc021bcc91bf181edb88664d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f6e65ec0a6841a94e0be1adc020054a8f297d63d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/346841659c17d8f4ef7d6d8c778a207ca1b8c29d',
#       'width': 64}],
#     'name': '7',
#     'release_date': '2019-09-27',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:19uWOx2aMKl7cdesfEyFms'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uRxRKC7d9zwYGSRflTKDR'},
#      'href': 'https://api.spotify.com/v1/artists/1uRxRKC7d9zwYGSRflTKDR',
#      'id': '1uRxRKC7d9zwYGSRflTKDR',
#      'name': 'SAULT',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uRxRKC7d9zwYGSRflTKDR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 187335,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UKMEH1900025'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5h12sLnQBTJ6yVqbRPNGBq'},
#    'href': 'https://api.spotify.com/v1/tracks/5h12sLnQBTJ6yVqbRPNGBq',
#    'id': '5h12sLnQBTJ6yVqbRPNGBq',
#    'is_local': False,
#    'name': 'Feel so Good',
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a0fff0e4b4dc120d336486ea4d82fe251c947038?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5h12sLnQBTJ6yVqbRPNGBq'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:22:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cZQSpDsxgKIX2yW5OR9Ot'},
#       'href': 'https://api.spotify.com/v1/artists/1cZQSpDsxgKIX2yW5OR9Ot',
#       'id': '1cZQSpDsxgKIX2yW5OR9Ot',
#       'name': 'Lennon Stella',
#       'type': 'artist',
#       'uri': 'spotify:artist:1cZQSpDsxgKIX2yW5OR9Ot'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/66W9LaWS0DPdL7Sz8iYGYe'},
#       'href': 'https://api.spotify.com/v1/artists/66W9LaWS0DPdL7Sz8iYGYe',
#       'id': '66W9LaWS0DPdL7Sz8iYGYe',
#       'name': 'JP Saxe',
#       'type': 'artist',
#       'uri': 'spotify:artist:66W9LaWS0DPdL7Sz8iYGYe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/675YaDMIisMe9ptwytmYJx'},
#     'href': 'https://api.spotify.com/v1/albums/675YaDMIisMe9ptwytmYJx',
#     'id': '675YaDMIisMe9ptwytmYJx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27352ceda0f27ae7d108a83d5a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0252ceda0f27ae7d108a83d5a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485152ceda0f27ae7d108a83d5a3',
#       'width': 64}],
#     'name': 'Golf On TV feat. JP Saxe',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:675YaDMIisMe9ptwytmYJx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cZQSpDsxgKIX2yW5OR9Ot'},
#      'href': 'https://api.spotify.com/v1/artists/1cZQSpDsxgKIX2yW5OR9Ot',
#      'id': '1cZQSpDsxgKIX2yW5OR9Ot',
#      'name': 'Lennon Stella',
#      'type': 'artist',
#      'uri': 'spotify:artist:1cZQSpDsxgKIX2yW5OR9Ot'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/66W9LaWS0DPdL7Sz8iYGYe'},
#      'href': 'https://api.spotify.com/v1/artists/66W9LaWS0DPdL7Sz8iYGYe',
#      'id': '66W9LaWS0DPdL7Sz8iYGYe',
#      'name': 'JP Saxe',
#      'type': 'artist',
#      'uri': 'spotify:artist:66W9LaWS0DPdL7Sz8iYGYe'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 192000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQX92000320'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5xROgo35i9a9IbQgN56Clz'},
#    'href': 'https://api.spotify.com/v1/tracks/5xROgo35i9a9IbQgN56Clz',
#    'id': '5xROgo35i9a9IbQgN56Clz',
#    'is_local': False,
#    'name': 'Golf On TV feat. JP Saxe',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a02994ec6b3f74e83872506eb3ca642ee97bf84d?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5xROgo35i9a9IbQgN56Clz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:25:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#       'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#       'id': '6LuN9FCkKOj5PcnpouEgny',
#       'name': 'Khalid',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#       'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#       'id': '6nS5roXSAGhTGr34W6n7Et',
#       'name': 'Disclosure',
#       'type': 'artist',
#       'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0uLz2ygHQAtLknyGasJOr5'},
#     'href': 'https://api.spotify.com/v1/albums/0uLz2ygHQAtLknyGasJOr5',
#     'id': '0uLz2ygHQAtLknyGasJOr5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/d2ee32cd210d22a19dece8956da265164dfe4573',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/75a8e57341e99a772e512166a99b9371428fc848',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a3944e7f1d4cd5de0f7d8d426e784bb5ae6ef755',
#       'width': 64}],
#     'name': 'Know Your Worth',
#     'release_date': '2020-02-04',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0uLz2ygHQAtLknyGasJOr5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#      'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#      'id': '6LuN9FCkKOj5PcnpouEgny',
#      'name': 'Khalid',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#      'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#      'id': '6nS5roXSAGhTGr34W6n7Et',
#      'name': 'Disclosure',
#      'type': 'artist',
#      'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 181436,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC11903871'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0TrPqhAMoaKUFLR7iYDokf'},
#    'href': 'https://api.spotify.com/v1/tracks/0TrPqhAMoaKUFLR7iYDokf',
#    'id': '0TrPqhAMoaKUFLR7iYDokf',
#    'is_local': False,
#    'name': 'Know Your Worth',
#    'popularity': 84,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e17f3c50aa16971cb93179073fd9a9e981a1a338?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0TrPqhAMoaKUFLR7iYDokf'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:25:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#       'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#       'id': '2cFrymmkijnjDg9SS92EPM',
#       'name': 'blackbear',
#       'type': 'artist',
# ...
#       'href': 'https://api.spotify.com/v1/artists/5p7f24Rk5HkUZsaS3BLG5F',
#       'id': '5p7f24Rk5HkUZsaS3BLG5F',
#       'name': 'Hailee Steinfeld',
#       'type': 'artist',
#       'uri': 'spotify:artist:5p7f24Rk5HkUZsaS3BLG5F'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2gjtjSAbxvoeQs6zYHj1HJ'},
#     'href': 'https://api.spotify.com/v1/albums/2gjtjSAbxvoeQs6zYHj1HJ',
#     'id': '2gjtjSAbxvoeQs6zYHj1HJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5cfdc92360d4f7a6a07172ef28d55ff1fa7be044',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/c4253b5b08b06aac46923ff0c581395b600892c8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/eb8d4decf00b161f62ca6751979b57f104d8eda4',
#       'width': 64}],
#     'name': 'Wrong Direction',
#     'release_date': '2020-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2gjtjSAbxvoeQs6zYHj1HJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5p7f24Rk5HkUZsaS3BLG5F'},
#      'href': 'https://api.spotify.com/v1/artists/5p7f24Rk5HkUZsaS3BLG5F',
#      'id': '5p7f24Rk5HkUZsaS3BLG5F',
#      'name': 'Hailee Steinfeld',
#      'type': 'artist',
#      'uri': 'spotify:artist:5p7f24Rk5HkUZsaS3BLG5F'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 248986,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71925619'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7GCVboEDzfL3NKp1NrAgHR'},
#    'href': 'https://api.spotify.com/v1/tracks/7GCVboEDzfL3NKp1NrAgHR',
#    'id': '7GCVboEDzfL3NKp1NrAgHR',
#    'is_local': False,
#    'name': 'Wrong Direction',
#    'popularity': 78,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7GCVboEDzfL3NKp1NrAgHR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T19:54:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2eam0iDomRHGBypaDQLwWI'},
#       'href': 'https://api.spotify.com/v1/artists/2eam0iDomRHGBypaDQLwWI',
#       'id': '2eam0iDomRHGBypaDQLwWI',
#       'name': 'Bleachers',
#       'type': 'artist',
#       'uri': 'spotify:artist:2eam0iDomRHGBypaDQLwWI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/10HKbC9lKDHGQvndGck6XJ'},
#     'href': 'https://api.spotify.com/v1/albums/10HKbC9lKDHGQvndGck6XJ',
#     'id': '10HKbC9lKDHGQvndGck6XJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d92afcf66072c83e4b28c6bb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d92afcf66072c83e4b28c6bb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d92afcf66072c83e4b28c6bb',
#       'width': 64}],
#     'name': 'Gone Now',
#     'release_date': '2017-06-02',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:10HKbC9lKDHGQvndGck6XJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2eam0iDomRHGBypaDQLwWI'},
#      'href': 'https://api.spotify.com/v1/artists/2eam0iDomRHGBypaDQLwWI',
#      'id': '2eam0iDomRHGBypaDQLwWI',
#      'name': 'Bleachers',
#      'type': 'artist',
#      'uri': 'spotify:artist:2eam0iDomRHGBypaDQLwWI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 193413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC11700733'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1K13OsIMc0HLgEJHZoWH78'},
#    'href': 'https://api.spotify.com/v1/tracks/1K13OsIMc0HLgEJHZoWH78',
#    'id': '1K13OsIMc0HLgEJHZoWH78',
#    'is_local': False,
#    'name': 'Goodmorning',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/93b8a732591bbc7a5489e02c1cb74cccacbe5a4e?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1K13OsIMc0HLgEJHZoWH78'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T20:19:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eCmccnRwPmRnWPw61x6jM'},
#       'href': 'https://api.spotify.com/v1/artists/7eCmccnRwPmRnWPw61x6jM',
#       'id': '7eCmccnRwPmRnWPw61x6jM',
#       'name': 'SHY Martin',
#       'type': 'artist',
#       'uri': 'spotify:artist:7eCmccnRwPmRnWPw61x6jM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6u4ZwK6xSWHhREBVzhjQg6'},
#     'href': 'https://api.spotify.com/v1/albums/6u4ZwK6xSWHhREBVzhjQg6',
#     'id': '6u4ZwK6xSWHhREBVzhjQg6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/fd15d35044b149e9ea45af58fdb87ee1be3ac966',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/485af8fdb722bdf91eaef9cb216d27de384c78e6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/214c3721586586dfadb65989a6c404abed440466',
#       'width': 64}],
#     'name': 'Slow',
#     'release_date': '2020-01-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6u4ZwK6xSWHhREBVzhjQg6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eCmccnRwPmRnWPw61x6jM'},
#      'href': 'https://api.spotify.com/v1/artists/7eCmccnRwPmRnWPw61x6jM',
#      'id': '7eCmccnRwPmRnWPw61x6jM',
#      'name': 'SHY Martin',
#      'type': 'artist',
#      'uri': 'spotify:artist:7eCmccnRwPmRnWPw61x6jM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 163547,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'SE5262000101'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Ia95g66IhlAJ3qVI4qI8W'},
#    'href': 'https://api.spotify.com/v1/tracks/1Ia95g66IhlAJ3qVI4qI8W',
#    'id': '1Ia95g66IhlAJ3qVI4qI8W',
#    'is_local': False,
#    'name': 'Slow',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5c1eefaf952cd3a476ef355422d9ad02a43567f4?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1Ia95g66IhlAJ3qVI4qI8W'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T20:19:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#       'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#       'id': '5INjqkS1o8h1imAzPqGZBb',
#       'name': 'Tame Impala',
#       'type': 'artist',
#       'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/31qVWUdRrlb8thMvts0yYL'},
#     'href': 'https://api.spotify.com/v1/albums/31qVWUdRrlb8thMvts0yYL',
#     'id': '31qVWUdRrlb8thMvts0yYL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27358267bd34420a00d5cf83a49',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0258267bd34420a00d5cf83a49',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485158267bd34420a00d5cf83a49',
#       'width': 64}],
#     'name': 'The Slow Rush',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:31qVWUdRrlb8thMvts0yYL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#      'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#      'id': '5INjqkS1o8h1imAzPqGZBb',
#      'name': 'Tame Impala',
#      'type': 'artist',
#      'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 366066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUUM71900928'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1KcOU0q9AMXV9xi4tSzzCc'},
#    'href': 'https://api.spotify.com/v1/tracks/1KcOU0q9AMXV9xi4tSzzCc',
#    'id': '1KcOU0q9AMXV9xi4tSzzCc',
#    'is_local': False,
#    'name': 'Posthumous Forgiveness',
#    'popularity': 72,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1KcOU0q9AMXV9xi4tSzzCc'},
#   'video_thumbnail': {'url': None}}]

# %%
sp.playlist_tracks(playlist_ids[0])['items'][0]['track']['id']
# Out:
# '4AQzk2yNWKs6sYhZi6NzVN'

# %%
def playlist_track_ids(playlist_id):
    results = sp.playlist_tracks(playlist_id)['items']
    return [results[i]['track']['id'] for i in range(len(results))]

# %%
playlist_track_ids('3bLernfiQrf45Ur8YqZIKI')
# Out:
# ['4AQzk2yNWKs6sYhZi6NzVN',
#  '7kQkmyoHCEqwe7QwDbkSXM',
#  '3jjujdWJ72nww5eGnfs2E7',
#  '57RA3JGafJm5zRtKJiKPIm',
#  '45S5WTQEGOB1VHr1Q4FuPl',
#  '4l0Mvzj72xxOpRrp6h8nHi',
#  '3eoNUm0LU9hATVVi9w4fM6',
#  '3ClBKQkKoaUQ6UOhe2xlJK',
#  '6S1x6w8CThgLiozbAOZ4zo',
#  '6QTPacyXkZWG9FMwq6L1hJ',
#  '6N22FZs2ZhPBYi3b9XPajV',
#  '3ZCTVFBt2Brf31RLEnCkWJ',
#  '6U0FIYXCQ3TGrk4tFpLrEA',
#  '4EWBhKf1fOFnyMtUzACXEc',
#  '2J3SR4n0YiQYCsghgeqZcB',
#  '3GRSqlALWISqLeNncZMbpX',
#  '1a0Mg4XPdt4EKsUz5beRZY',
#  '0xM6mdl0XX2qOqUZmVUp97',
#  '4RE3vueod5PL48rvHtuu9C',
#  '4yJiXq86uM56uIfIZgE440',
#  '7zs9aoWKrINoC5ZXL7OvRm',
#  '2Yv2mHzr5AQavVdwQjEokV',
#  '2C0hTkdEoikhKzDCJl32QZ',
#  '7oIAqDzsqgVpUaMXuultdC',
#  '6qQ8a6M6o5mfj9wTdrbSgG',
#  '1yaWRS9r2woTNmJpCKd5l9',
#  '0yTlrnue3pJTJd7h7d43mk',
#  '3AHqaOkEFKZ6zEHdiplIv7',
#  '1FCwkiooaMCY8YpQdSJ0Gc',
#  '4NK49OnNDP3oJcTGs89XSg',
#  '5CHrPezdekgcVhWiUuDqHH',
#  '0ZMBqlhWnSlR4KCiUfLL8i',
#  '7zTTDkkLkJ2iHAqq1daDCr',
#  '5hrbuCjGxws7txUEr8XDgb',
#  '7hV7333ajQNI1J6R5C9A8c']

# %%
def playlist_pipeline(user):
    playlists = sp.user_playlists(user)['items']
    playlist_ids = [p['id'] for p in playlists]
    
    return {sp.playlist(p)['name']: playlist_track_ids(p) for p in playlist_ids}

# %%
playlist_pipeline(my_user_id)
# Out:
# {'2020-v1': ['4AQzk2yNWKs6sYhZi6NzVN',
#   '7kQkmyoHCEqwe7QwDbkSXM',
#   '3jjujdWJ72nww5eGnfs2E7',
#   '57RA3JGafJm5zRtKJiKPIm',
#   '45S5WTQEGOB1VHr1Q4FuPl',
#   '4l0Mvzj72xxOpRrp6h8nHi',
#   '3eoNUm0LU9hATVVi9w4fM6',
#   '3ClBKQkKoaUQ6UOhe2xlJK',
#   '6S1x6w8CThgLiozbAOZ4zo',
#   '6QTPacyXkZWG9FMwq6L1hJ',
#   '6N22FZs2ZhPBYi3b9XPajV',
#   '3ZCTVFBt2Brf31RLEnCkWJ',
#   '6U0FIYXCQ3TGrk4tFpLrEA',
#   '4EWBhKf1fOFnyMtUzACXEc',
#   '2J3SR4n0YiQYCsghgeqZcB',
#   '3GRSqlALWISqLeNncZMbpX',
#   '1a0Mg4XPdt4EKsUz5beRZY',
#   '0xM6mdl0XX2qOqUZmVUp97',
#   '4RE3vueod5PL48rvHtuu9C',
#   '4yJiXq86uM56uIfIZgE440',
#   '7zs9aoWKrINoC5ZXL7OvRm',
#   '2Yv2mHzr5AQavVdwQjEokV',
#   '2C0hTkdEoikhKzDCJl32QZ',
#   '7oIAqDzsqgVpUaMXuultdC',
#   '6qQ8a6M6o5mfj9wTdrbSgG',
#   '1yaWRS9r2woTNmJpCKd5l9',
#   '0yTlrnue3pJTJd7h7d43mk',
#   '3AHqaOkEFKZ6zEHdiplIv7',
#   '1FCwkiooaMCY8YpQdSJ0Gc',
#   '4NK49OnNDP3oJcTGs89XSg',
#   '5CHrPezdekgcVhWiUuDqHH',
#   '0ZMBqlhWnSlR4KCiUfLL8i',
#   '7zTTDkkLkJ2iHAqq1daDCr',
#   '5hrbuCjGxws7txUEr8XDgb',
#   '7hV7333ajQNI1J6R5C9A8c'],
#  'cold out 2019': ['7ce20yLkzuXXLUhzIDoZih',
#   '7qEHsqek33rTcFNT9PFqLf',
#   '4a5zacCsHLtMC2mcxkqWwn',
#   '60iSKGrGazRzICtMjADNSM',
#   '1Fo4OvzP9PThFKMeMIAEYu',
#   '4fFfyouye6vrX9o9z4PVMu',
#   '5C1TucCRf4Vjjree1OItyv',
#   '4RE3vueod5PL48rvHtuu9C',
#   '6GFfDRG1Sff3IZaD0TYro4',
#   '69vToJ9BMbbLlFZo7k7A7B',
#   '12OLyHDxt6dqlAybSPFBK3',
#   '2IqjKEBiz0CdLKdkXhxw84',
#   '0ZMBqlhWnSlR4KCiUfLL8i',
#   '4L2K7JKseFCBoHMZEAszW0',
#   '4Of7rzpRpV1mWRbhp5rAqG',
#   '2BOqDYLOJBiMOXShCV1neZ',
#   '1NxHgM5nOnmqi3KUVLbaIw',
#   '6glNKSv2aUtfQhe1SJBZZt',
#   '5UqivtkoiPTXrJu6GIt1mh',
#   '4GGSmoTmc5LClrowB4SmEw',
#   '7zTTDkkLkJ2iHAqq1daDCr',
#   '53G729jc38JTStNPNX4dF1',
#   '6Ti0coAmnSsv3Wx09RhoY6',
#   '6U0FIYXCQ3TGrk4tFpLrEA',
#   '64BjH0cofoZQLz7STwGqyw',
#   '47Bg6IrMed1GPbxRgwH2aC',
#   '0YdIIMb2MHuxoUudkAY9gS',
#   '4tVphly4D1PB8tJC9gHMcJ',
#   '3SxSrUogj4LpAkLKXeTtTQ',
#   '1a0Mg4XPdt4EKsUz5beRZY',
#   '5RxpYHVbGJPOvSEATQyg9P',
#   '01z2fBGB8Hl3Jd3zXe4IXR',
#   '7uNUSxzFjPj9JQaZidFreW',
#   '2kJwzbxV2ppxnQoYw4GLBZ',
#   '1ZMiCix7XSAbfAJlEZWMCp',
#   '3GRSqlALWISqLeNncZMbpX',
#   '2J3SR4n0YiQYCsghgeqZcB',
#   '2SCUNHTUORvAnmWjSsp5Ib',
#   '0xM6mdl0XX2qOqUZmVUp97',
#   '5WkCcSa78lM1Ym4LXzJUiN',
#   '0Npijoc6ZcUe1devUugKvI',
#   '6YhM7gYdksUvENbGxsQxxo',
#   '3jjujdWJ72nww5eGnfs2E7',
#   '2cM5JyfLJqA4B0SS2QrGxI',
#   '3AO00ixxqEBEwpGMb63BQ9',
#   '3ernkvxpkWap60SeadSqGL',
#   '6VWz99969QmNc2gWo21ktl',
#   '5bbxBlkH2QdB1AkA0JIx36',
#   '7kQkmyoHCEqwe7QwDbkSXM',
#   '4AQzk2yNWKs6sYhZi6NzVN'],
#  'fall 2019': ['7dxKdQC9Vo1hDxIUnt1z0Q',
#   '4fCAOaMs0PYL58OijKp2IS',
#   '6wo37KVqFJhtuxPTpLCcfe',
#   '3LxG9HkMMFP0MZuiw3O2rF',
#   '70YPzqSEwJvAIQ6nMs1cjY',
#   '330cmrgtnIj4NtPTYdDOZv',
#   '39n1y2JqVOPIdfUeLqzgfl',
#   '0yc37FvbXRwwFaQxzpxbsd',
#   '3Fm4KEBiLmj4e3x4Qqv7W0',
#   '1pBO9JDqh1y3TbCKEO1OvG',
#   '0y675KDleCZEudjoeL1sQQ',
#   '6EBlOYNcZ8MrdEov9lEdV6',
#   '4a5zacCsHLtMC2mcxkqWwn',
#   '6aoGtdWXBkYQ2O2wnyIz2x',
#   '6tPnAqe6UNeKMoOrruBSEi',
#   '4pioeMejnqa4T3QAEqwVA3',
#   '0s5ibKUNbISHnrBrx1o2nF',
#   '4vsAUbPb6q9FpC4AGBFdVh',
#   '3EY1vEkydU2oguC17jzhTZ',
#   '5bQ1qgqZhpCS9RQCUZaqBO',
#   '1gGhqfs2pDTOI30AEXMXrn',
#   '4fwo6czG5nvOQMzhOto1ya',
#   '21jGcNKet2qwijlDFuPiPb',
#   '1YscJ7yVTlFxW3eF6pv5ba',
#   '3uouaAVXpQR3X8RYkJyitQ',
#   '63UNqAjFomMcZXc2InOxTC',
#   '5Cevkgj9FyNRFIwY3xSCn8',
#   '7sJwGtoWgkVRwzujlyT3cp',
#   '0ijiuWyVbNzg6Kw1Z1BVb8',
#   '3xaugmCyXrVkrDTXbFkMW3',
#   '1cHI3DxIBY3HKUnCI5I71B',
#   '2h3jBh2kDDRSDbwzJqelFx',
#   '0tByDZgQzoNfFFmpgleB0s',
#   '3qbqWUDl9j09PeBaQ6CZgr',
#   '37mfTcSlX60JtAvAETytGs',
#   '2v5JTeM6hSmi5wWy7jiwrI',
#   '5uIRujGRZv5t4fGKkUTv4n',
#   '35Ki1lvKPC2sFBD3GmKdRG',
#   '1Bn8jBSmtSQdvAFXU3ok1w',
#   '1vsQb8n0icvMsFnL9663LM'],
#  'cold out 2018': ['6HguG9HRb1Ke1bhihfE4m8',
#   '3TgMcrV32NUKjEG2ujn9eh',
#   '4rmIfFUZhhi9sS5IYtpkXw',
#   '18UsAG7SfOQ5sxJEdjAMH0',
#   '1Fo4OvzP9PThFKMeMIAEYu',
#   '6jMbPsH6lTOLs5n8Af26AG',
#   '4fFfyouye6vrX9o9z4PVMu',
#   '6e2PtJYcltVk76nLwxBzRn',
#   '38hsyezZR0s5CxAwpKo2G1',
#   '5UFvcTCbp9P057YbRNsJ3U',
#   '7GbAp0HKPQW7WnFJAzMoRk',
#   '0Eqg0CQ7bK3RQIMPw1A7pl',
#   '3D110t9ctcoOoylXsc3iR8',
#   '7ArrTJ1LwcGAlEO65LUQ7i',
#   '6fFTPGGItuEpjwXRUIr4rk',
#   '5hc71nKsUgtwQ3z52KEKQk',
#   '2hnxrRNzF74mdDzpQZQukQ',
#   '1A6OTy97kk0mMdm78rHsm8',
#   '1TPLsNVlofwX1txcE9gZZF',
#   '2J0X46UkpfLlWbuCXFgDLr',
#   '1RMJOxR6GRPsBHL8qeC2ux',
#   '7zFXmv6vqI4qOt4yGf3jYZ',
#   '23c9gmiiv7RCu7twft0Mym',
#   '7i1pavASRUZk62ejaUIESa',
#   '0KyzXQhY2yzcb1FYCHkZc2',
#   '6A1GBCMwbfhkB9e1thR8a8',
#   '65Bynqyt59f3fojjs1Uo41',
#   '6A9mMKHYdeUJGvQDKChC0C',
#   '5JEx7HbmvHQQswJCsoo9rA',
#   '0rKtyWc8bvkriBthvHKY8d',
#   '14sOS5L36385FJ3OL8hew4',
#   '3kYARoLSAvt86VFZ55BQcq',
#   '2qXicQG06oT0ijKBznpgQv',
#   '2kJqNHHGOzLNahukdvlDWN',
#   '0IVHlst3XMgzXUJbIyZ8oO',
#   '5boqkVlc0CWhfTjksnpc1X',
#   '4KQ3hT01bWE952ghVbxBtW',
#   '4VUwkH455At9kENOfzTqmF',
#   '3K8tRD2Prik7FXbD8lZ6DC',
#   '2jZIfoe48eUeOEnP9Ho4h2'],
#  'autumn 2018': ['61IZ68GrpFuNWIJPq77Kzw',
#   '6TodWdTSDfzwgYynTZSvJn',
#   '7ghXLHZjZtZiiQhFfhyeY4',
#   '6Ov2pt0TfDeSdNHfdlcKpq',
#   '1aDyeu6FGxYwTpoAW4It6g',
#   '4QjtXlzepoVp3YXMvwxyyr',
#   '4gB61mP4tNChn4LgfquMhi',
#   '38hsyezZR0s5CxAwpKo2G1',
#   '6e2PtJYcltVk76nLwxBzRn',
#   '3DK6m7It6Pw857FcQftMds',
#   '2JVwsN6viHjR9t5pCPQ4Br',
#   '6XyZgbnWyA6LzOgCr0mOIy',
#   '0vG2V29bRz4uZWtCandbh2',
#   '5boqkVlc0CWhfTjksnpc1X',
#   '75ls0gurX68lUmMjE7QcsE',
#   '3xzmbGtaMnGUUhOcvqIN05',
#   '0bf2XtxP5RsUYqWdsjk58H',
#   '6HZILIRieu8S0iqY8kIKhj',
#   '4hQ6UGyWQIGJmHSo0J88JW',
#   '07ipXN6CNTw34qwSYePKpg',
#   '5iRnQIh9VxMRp26OFFWH6z',
#   '5SA3BsojSPRfL6zhuyi0N2',
#   '5lK18Pt33xNudq4qYDxIm8',
#   '2lYTJK94hb0fd1LQtb6Dhk',
#   '3JJYIoJ5FyY9E0DGjr7SXF',
#   '328QDttJ2uYhtFyFmsiuI6',
#   '12gnUTEnxL6PYN06RX2Je1',
#   '4mEILaBM7bKZqKAun5tABu',
#   '4fFfyouye6vrX9o9z4PVMu',
#   '43nPCguApD0kcM1qiqfyHh',
#   '41CgzGD7xlgnJe14R4cqkL',
#   '1Dr5JexwA15wmKe7Y7maA9',
#   '35GS3Vh3ouARXMpsmZeXJy',
#   '4dpD3TDufxz2rQ9JLkYPgV',
#   '1FjHxl8B28sXj7eVfxdST4',
#   '1FFKRJnZX9xT4U5zW0suuR',
#   '4Y6eeE8HKXWi4ACheV2SAN',
#   '0SvxydoxEEkXt9aMAqTfpB',
#   '6KuU2rnFYUyYzGOwcCZDT7',
#   '2dpaYNEQHiRxtZbfNsse99',
#   '4QVS8YCpK71R4FsxSMCjhP',
#   '7BS6Xfx1NOJbEy4TE9TPAM',
#   '3JXuMsnzwmqEEqQexK0q8b',
#   '6jMbPsH6lTOLs5n8Af26AG',
#   '35xSkNIXi504fcEwz9USRB',
#   '5UFvcTCbp9P057YbRNsJ3U',
#   '1Su4HXSrbzj02CPBOoVLli',
#   '3EIaMTBMRM42nbEROLg7cZ',
#   '0oagwWkGlBoACUuKvTmqZV',
#   '1csB4kgdyglOQdH0EyFIqy',
#   '1r7J1I74FgrxkmJ6kJBKs6',
#   '1Fo4OvzP9PThFKMeMIAEYu',
#   '0D4yVl9Pn45xW2s63MFCmT'],
#  'residual teenage angst': ['5dY6NfWkgfKCH2E9mt4wcg',
#   '3JOdLCIBzQYwHIvpN3isVf',
#   '2fmCA13dwQQOGBIbIOWRiJ',
#   '6EE19skJ32p58xihYj2Waa',
#   '3Zwu2K0Qa5sT6teCCHPShP',
#   '7j31rVgGX9Q2blT92VBEA0',
#   '3yZQk5PC52CCmT4ZaTIKvv',
#   '5KAgd2yW7tktrKDsJhO9Fr',
#   '028njLMKzGg4gAVSgMeOhm',
#   '2WWP0IPX9xFjAMraNHX390',
#   '3nSiB5WCF2pmRQrYSsteHv',
#   '4UuHWIkAWnN176A2rx7YFB',
#   '0wVluBsVAVzBKrqspuCcwR',
#   '5lDriBxJd22IhOH9zTcFrV',
#   '0gZp88SA5OcujHLDGkxtI3',
#   '0l2p5mDOP3czJ2FpD6zWie',
#   '6PurllVXXGL1s6UkLtzMVF',
#   '3ZaS7Bcz9tpFIjfst63tSw',
#   '14mqKOS4dHMf48spDuzfYv',
#   '60OyEYORxZjS7xlfoAgyjR',
#   '6L89mwZXSOwYl76YXfX13s',
#   '2TfSHkHiFO4gRztVIkggkE',
#   '0J69x3mqm7U6tBPKsjpsWR',
#   '7yCPwWs66K8Ba5lFuU2bcx',
#   '3mcG2NI5G5vhrQtRda1YnA',
#   '1HNE2PX70ztbEl6MLxrpNL',
#   '0a7BloCiNzLDD9qSQHh5m7',
#   '4wzjNqjKAKDU82e8uMhzmr',
#   '1fJFuvU2ldmeAm5nFIHcPP',
#   '5dTHtzHFPyi8TlTtzoz1J9',
#   '1S30kHvkkdMkcuCTGSgS41',
#   '0jqK7sGTLsHPkQrrcrGuKD',
#   '0lP4HYLmvowOKdsQ7CVkuq',
#   '7oK9VyNzrYvRFo7nQEYkWN',
#   '6I1HRAkeErdwrOJIfRrfIO',
#   '1JURww012QnWAw0zZXi6Aa',
#   '70wYA8oYHoMzhRRkARoMhU',
#   '2nLtzopw4rPReszdYBJU6h',
#   '60a0Rd6pjrkxjPbaKzXjfq',
#   '0rOTMSSa6yscfOrGnzfheM',
#   '3iT4vWUWxqsn4hFTkEaJCi',
#   '0kYUrLVQOfx21xuXu7OGrT',
#   '0gmbgwZ8iqyMPmXefof8Yf',
#   '4KacUpvbA3Mfo05gttTjhN',
#   '4jVhSbMMHctghoOTFuLPB2',
#   '0dRdb2IIRJil2IW0Q9rYZC',
#   '1hIupFeRu3nmMcjbjxPnMc',
#   '10rChmECwPcvTTj4w07hq4',
#   '3SqOC9IRDYGSq9cH6K2GQI',
#   '0kdlNl7D6EEU4kSkvRKBb7',
#   '36UVZPoK8a1Oxh13cY8kOp',
#   '4RAOI1etsgbh5NP3T5R8rN',
#   '4bPQs0PHn4xbipzdPfn6du',
#   '2l57cfmCnOkwNX1tky02n1',
#   '4pmU8AtVu9qU40Xd9zjEfA',
#   '1FMHNVeJ9s1x1l1WlaRs2I',
#   '7naGWci9bflvfdzxphFjAw',
#   '5eB7w8UZJKjL5XmnC6Pctg',
#   '423FiDerFgzeEcqKEOmZ81',
#   '2ydUT1pFhuLDnouelIv4WH',
#   '2d6m2F4I7wCuAKtSsdhh83',
#   '3ZffCQKLFLUvYM59XKLbVm',
#   '27L8sESb3KR79asDUBu8nW',
#   '38z6jaLE0F13dxv28n3wlq',
#   '4z1gmF4S1YsTj1pxiU47Qx',
#   '3Dg1BK3rHo6mCvzSO2b9Ct',
#   '4WdopfTdSd0nCLropjhsgH',
#   '4VgEM12OeaN3GyBV487Me7',
#   '5GorCbAP4aL0EJ16frG2hd',
#   '23oxJmDc1V9uLUSmN2LIvx',
#   '6A9nyMBdNUzVcFHZUEZ71F',
#   '62Vulfjc2qjCWim4LWBvvc',
#   '2ZqTtndqAZDRAWw2vgZwQK',
#   '5BB0Jzw60KyfSTyjJqtely',
#   '0uukw2CgEIApv4IWAjXrBC',
#   '7HGTkn2aX7MNdKs7nV2xBt',
#   '2KbmrXsDOit0hvEdorMZ2o',
#   '1OTvWduKQV0MQd2gnGM9He',
#   '1MSAQKzTAJamjVjZDzlwRi',
#   '3rG8ZkmKHb4Ms6CsSzEITv',
#   '4qSsjDGXplb6422X2INvFW',
#   '5rLi8B8qgk6qThwRnKHW2P',
#   '2EGF4JrisrJ4D4HOdTyYEO',
#   '3eRLKD1Lgc2OrYGxRxX62s',
#   '0d8aJLKZI1r4uOSLZBJaBK',
#   '7ewT0nLFkMD8ONbRibePr9',
#   '12mF5rnbbT7jNqiBv8NBFt',
#   '46Kcradxrva9Dny4lHU1b3',
#   '1oagRT7LfpVlNJN6FSZDGp',
#   '48nnqkmwmjZ7ohyShSyKAm',
#   '1bhjMY5O0ZjB41OHcdRH0a',
#   '6nTiIhLmQ3FWhvrGafw2zj'],
#  'unemployed 2018': ['6e2PtJYcltVk76nLwxBzRn',
#   '4j3GWI86JvSaF0BLdmgcfF',
#   '1Nj2oBISdFDSF8eDuXcALz',
#   '58q2HKrzhC3ozto2nDdN4z',
#   '3xzmbGtaMnGUUhOcvqIN05',
#   '3ee8Jmje8o58CHK66QrVC2',
#   '1snWlbcbgQpJfknoI30DWG',
#   '5boqkVlc0CWhfTjksnpc1X',
#   '0b9oOr2ZgvyQu88wzixux9',
#   '0bf2XtxP5RsUYqWdsjk58H',
#   '328QDttJ2uYhtFyFmsiuI6',
#   '3EApebexZ7YqDIqw2EMTDh',
#   '5H0NU2sHWUnWCcZyYlX46X',
#   '6TrzifGqGOc2DfBbiXQtTz',
#   '3PdgIdRXJjgxfOr7slldel',
#   '6Bg7MznA9X0dIhlAsLyBYj',
#   '6dktyiCWz2JYGmcPQ5D5dY',
#   '6TodWdTSDfzwgYynTZSvJn',
#   '1MyfqyxGm8CvRU0P2OZcll',
#   '2cEnYJKLSZPH7MFSk6C05c',
#   '6HZILIRieu8S0iqY8kIKhj',
#   '6PGoSes0D9eUDeeAafB2As',
#   '51rXHuKN8Loc4sUlKPODgH',
#   '7IBSffWIu7P2MC7kMwy2FM',
#   '3DK6m7It6Pw857FcQftMds',
#   '1A6OTy97kk0mMdm78rHsm8'],
#  'killers panorama': ['7oK9VyNzrYvRFo7nQEYkWN',
#   '5aWhs651KYM26HYM16kRdk',
#   '7HGTkn2aX7MNdKs7nV2xBt',
#   '1A8SxnqRK3qabmuN2qxIpa',
#   '2ST5UpeYPp2EAgGLbQsXvl',
#   '2aZ2Co4NeQRsqWcU930zHT',
#   '5NAiPIEzxAexFE3ucV18Q8',
#   '4kAgnAL4WKx7YqnlL2fvMh',
#   '6suRRwX61xSMfU7wJuCVdy',
#   '6svrEn54rNuEo7Ta5dJslc',
#   '7cX4PJz1old9fyFI8RlfgW',
#   '0kYUrLVQOfx21xuXu7OGrT',
#   '70wYA8oYHoMzhRRkARoMhU',
#   '1sTsuZTdANkiFd7T34H3nb'],
#  "summer's end 2018": ['514rhnksEwHUh6LxXsQ4Y9',
#   '0VE4kBnHJUgtMf0dy6DRmW',
#   '4Y6eeE8HKXWi4ACheV2SAN',
#   '7HuBDWi18s4aJM8UFnNheH',
#   '2fZQIJew3nkNe99s2PKzul',
#   '40QQZP6LVXUP5h79Q5Yvke',
#   '1oc3jna2ablnfIKLYbKujl',
#   '6Yk4HTvs1Ww41l4c7iyBlH',
#   '1Nj2oBISdFDSF8eDuXcALz',
#   '07NxDD1iKCHbAldceD7QLP',
#   '3nc420PXjTdBV5TN0gCFkS',
#   '3T4UodGkfZObJ43RtA5KFU',
#   '3JJYIoJ5FyY9E0DGjr7SXF',
#   '5Ddp5V1M84fKmXbtDhASu0',
#   '3bH4HzoZZFq8UpZmI2AMgV',
#   '1jHg7bUEfa67jzcayP2SvK',
#   '6xTU6B6nFwKKTSZ9ySXS80',
#   '4E5IBDRu8kJbzUv1qaZM1t',
#   '6NFyWDv5CjfwuzoCkw47Xf',
#   '4keoy2fqgwGnbWlm3ZVZFa',
#   '5vsRm2aCBl5T2qdpvwtrf6',
#   '4gB61mP4tNChn4LgfquMhi',
#   '2PSeBKFabj27ud497FxQQy',
#   '4mEILaBM7bKZqKAun5tABu',
#   '3vHTlIT5uIilAFf6Cy69tr',
#   '7nZBRPj89rgeZ5eBLp2J7P',
#   '3xzmbGtaMnGUUhOcvqIN05',
#   '4j3GWI86JvSaF0BLdmgcfF',
#   '5BCnoG4uUCyz58OOy1kFeQ',
#   '2lYTJK94hb0fd1LQtb6Dhk',
#   '5boqkVlc0CWhfTjksnpc1X',
#   '5SxkdsY1ufZzoq9iXceLw9',
#   '70khXICDeTTxgYtw3EysKH',
#   '3EPXxR3ImUwfayaurPi3cm',
#   '0UvVZwaKrd4JRXS03D59p0',
#   '1avsdAHEznOhz5KFF04zOS',
#   '38hsyezZR0s5CxAwpKo2G1',
#   '4QjtXlzepoVp3YXMvwxyyr',
#   '0jPU39bL0SrCmYc1RwbFkX',
#   '75ls0gurX68lUmMjE7QcsE',
#   '3esogDu1xpfphICWKjd8fp',
#   '6e2PtJYcltVk76nLwxBzRn',
#   '1snWlbcbgQpJfknoI30DWG'],
#  'summer 2k18 pops': ['09IStsImFySgyp0pIQdqAc',
#   '2fZZPs9gwlUoAMJRayBWMk',
#   '6NFyWDv5CjfwuzoCkw47Xf',
#   '5sIx4BlfYGuZeSLF40N9GH',
#   '7dt6x5M1jzdTEt8oCbisTK',
#   '3swc6WTsr7rl9DqQKQA55C',
#   '3fpVWegR6YOS1Yk5HSMYIq',
#   '4H7WNRErSbONkM06blBoGc',
#   '5CLGzJsGqhCEECcpnFQA8x',
#   '76cy1WJvNGJTj78UqeA5zr',
#   '2Za1AlJNvksouPPWbXpR2X',
#   '2BNkTvg1kHAAfGvqh56x5a',
#   '2DlIwu1iDTILEMXA7MUotn',
#   '514rhnksEwHUh6LxXsQ4Y9',
#   '6Hgh47WXVKtXN5zGOu0hjI',
#   '1xy4apMFecGGkgBeaHFZ2M',
#   '01k24g94i1JvkFLQmVEdCd',
#   '5E5MqaS6eOsbaJibl3YeMZ',
#   '2z7UKVsBdbA7HFPunDKDP4',
#   '16XiTUC2rQvb5lmtOm3FYY',
#   '0SvxydoxEEkXt9aMAqTfpB',
#   '1etiUDkISHELzQGMY79ryt',
#   '619pVMIK3WvX529JIkQTY3',
#   '6eNnOg4CnJvjeRGfHQrHYJ',
#   '4Y6eeE8HKXWi4ACheV2SAN',
#   '2uH1LQKwcagDccsQHR8ac6',
#   '4gYKiJJ8wHAoqWXpn4bfij',
#   '7FkH8LndW3WmnwLvVhml4F',
#   '3u1S1OmAUhx5DRlLrXqyp3',
#   '0VE4kBnHJUgtMf0dy6DRmW',
#   '4mEILaBM7bKZqKAun5tABu'],
#  'senior spring pops': ['6XLUlVeCNo4T7Gvkmy6NmC',
#   '7hm9jQNKimMfU4ig9L8ldq',
#   '1ISGq0nLoMmNJgFxQeIBvZ',
#   '42CeaId2XNlxugDvyqHfDf',
#   '3aAoy02NwrmZcqXYYjqNh2',
#   '65PsOtxOpgaGvjztMGzoj2',
#   '64fwanXDvwmsQrLsDSVHMv',
#   '4LSkEJ5P5MV0y3PZqw7guJ',
#   '3AzvNvE3xpgelqmE5MRnbI',
#   '2glGP8kEfACgJdZ86kWxhN',
#   '4dqnFd0dfgh4HgZ1w3AGTE',
#   '0cOBMETjhxublnnwhbnzJO',
#   '1So1tVk3gybvc2I0JY8K22',
#   '4giSIrLAdUbzfBBqSvaM6C',
#   '4yb3ikgJkgBNTSkGm2Lvhz',
#   '27eoCHVL1mohdzR7c61KQ1',
#   '0dzKKW6FzIT7C38BdQBbgw',
#   '5ZuInVOgNrq49O6XtYpjq1',
#   '2ULg8Cw0Ckn5JDGUkCNXko',
#   '1wfZdPy5FRWsdWaAEOG0Ml',
#   '5l66zJX4PpyS7b5DgoNJX9',
#   '2CgOd0Lj5MuvOqzqdaAXtS',
#   '7GYLsGlCPqSkLBNDC5mVyl',
#   '1P1cqHF1QS4HR194MruFTy',
#   '00c9VpjXk7iHdLEEzrAxbr',
#   '720VccfW5GV9ZM4OKAAGUg',
#   '0iKvoS34v7uybtIXsOqvon',
#   '1euQrkGwRPQod7kcddoeJ5',
#   '1W0zPxHrUF4H2xmWkO97Ea',
#   '5be60DE1dTfKoeyxQj0tR0',
#   '3bUApnYMVCEs2Ds9FsXGs5',
#   '5WggjuxMubr94bo33Aan4K',
#   '7KT7VGnPU5QVXN3q1BOeqb',
#   '64kyLirkv938cCbWBjLOTg',
#   '2BNkTvg1kHAAfGvqh56x5a',
#   '6AnX0PDwtqT6XxlwzDpThW',
#   '7wrDRQgHlvDnimrRHfQZxt',
#   '2XW4DbS6NddZxRPm5rMCeY',
#   '45Egmo7icyopuzJN0oMEdk',
#   '2ARqIya5NAuvFVHSN3bL0m',
#   '66kQ7wr4d2LwwSjr7HXcyr',
#   '2bllegdYt2WoYdbRZyJ730',
#   '5uu28fUesZMl89lf9CLrgN',
#   '7I49KefHnQONDAhR3A6jxX',
#   '04AYgtKFrpldRXe5y0LNGQ',
#   '7os1J5P6JqIxKSxq71QuQC',
#   '1eyrmeiDpdTkOmA839nPVQ',
#   '6ISionOfm9VCredgDEUSIG',
#   '3qaYuV5XZAwiOvGE91HhwS',
#   '6A8dnC0xkiuWN4BshmTB2I',
#   '5ffwgrvw4tVlhFcI8efviN',
#   '7vGuf3Y35N4wmASOKLUVVU',
#   '6jq6rcOikCZAmjliAgAmfT',
#   '2WWfjbHALIb3e7FMcj9mr4',
#   '5iPnsVuITetx7KctVo7RW9',
#   '4GJAd1nBylAEbw1dZDVzEQ',
#   '01iyINEYgPQ7ThMZuHUsqS',
#   '6UiDiFJUGEDzkGpZBL8IYq',
#   '36fRbuu9QkKVDR1j7jTI2U',
#   '023iguyZD2x6yCSJDYxfyQ',
#   '6KuqAtoeVzxAYOaMveLNpH',
#   '0Wx0LdOS71tOoBsxETFz1o',
#   '3OIZ2cAh5Yu1AILuVd9D9c',
#   '70rTF2IuUFSqu0QTWXEpqw',
#   '5sIx4BlfYGuZeSLF40N9GH',
#   '5TR3sdi4QH0qwIsZ6CqJa3',
#   '5FZyParKWrsTrmSKhhKClw',
#   '0VE4kBnHJUgtMf0dy6DRmW'],
#  'acoustics': ['1mXB4iHWsfCmjO5mCUf3Ts',
#   '3Xzqm3Fuof3LEkyFIInfT4',
#   '19erZJyJBa4PGODP5fXGvp',
#   '4SpVCOrSfXuDTnpInrNhzU',
#   '5CsRDK4Nitj3hxY7VnGlGI',
#   '2iaMA9ggKF8l1kxx9tEA0U',
#   '0HP8e0rfD5dkxTYMPq3BF6',
#   '7q0aQpiLv5tIsupcgQ3Ny4',
#   '7K6LFPfjdnN6QqvGzhvpRO',
#   '3Kj2EWpIBnvETsYq4cq0IH',
#   '4fbvXwMTXPWaFyaMWUm9CR',
#   '75W4O60nl3FiUZFwE1LzbQ',
#   '7c71baHwrGDOeIFl1gVO14',
#   '3JfIm2Wib8oVWkYMgkVWfa',
#   '7lbiZC0DtKc9TSCO2wyUPf',
#   '1fN1XSvh1gubVjx9ZbI6mg',
#   '45FrYVS9BScbfO8lujdsW0',
#   '2tyRWdJpAqiChivdkU8M7r',
#   '3pLTOP0G0etiWUknFoRpsr',
#   '6liNJDyWJjyHAgDnAX95bw',
#   '7tmtOEDxPN7CWaQWBsG1DY',
#   '41yIvlFgvGwxq8qTqAR7eG',
#   '5YqpHuXpFjDVZ7tY1ClFll',
#   '5OiaAaIMYlCZONyDBxqk4G',
#   '3G9ETaH55bMQx8hwNhAgbU',
#   '2BOof6lYrGfz6BojJ0aeJd',
#   '5HF5PRNJ8KGtbzNPPc93tG',
#   '0fqjy5gVNVmQQmxOLLfb3c',
#   '45p0MAVey0dnjZXo8kMUzh',
#   '2c62Xf5Po1YSa1N6LOjPHy',
#   '7CEV9VwA8XO9wwxTXgYKvY',
#   '2gUSIsapdX6jEJ0DvjqTt2',
#   '1vyrrrnb7182SL6iOMor3O',
#   '0tp63L82d21GTlvZuKSHGY',
#   '7A0FGrZsLgOUmeNtMTnt4z',
#   '47KDDZgFiX1w6RFOuLXsSn',
#   '0BDD36DWIc0nY5rqMptpSk',
#   '3RPerpXuNznZbCuWYEBz5i',
#   '1ueeLdAauagzEJ9coJQMYt',
#   '6Qwuw0eOeszVlewLpu24gR',
#   '4OFx2sTI1L2lJWiJCCTECL',
#   '5eXnC2B5RU5fAhfwvV2ABD',
#   '1OwHOfTeJkdRhdqq93y2XV',
#   '5kRPPEWFJIMox5qIkQkiz5',
#   '70HWRkitkAKfos500LBk0T',
#   '78O8CIzX5ZMuJh39fQOR3i',
#   '7o7CXsKgDXhxbSMrqGVSd0',
#   '0WTQ3OVvyuD49BfO99Q6y7',
#   '6vSwxzO2Qf4BinHSXRwZJe',
#   '2dfHh7ECGxfNqZTQno09Vk',
#   '0Dv23k5ErS9XO9U2BYRI0F',
#   '0QZ5yyl6B6utIWkxeBDxQN',
#   '5pBZoZhlYKgzdjdqtbBeXX',
#   '1aDyeu6FGxYwTpoAW4It6g',
#   '3EIaMTBMRM42nbEROLg7cZ',
#   '2Y5v72rZR7ym6LRbh5NilJ',
#   '1Su4HXSrbzj02CPBOoVLli',
#   '3vd1kGy66qEnvWJHGLeiRe',
#   '7BS6Xfx1NOJbEy4TE9TPAM',
#   '2uhEKg8kIzpdvz4gyy6x8W',
#   '5ngcqrs4Xq915GUqNtNNr5',
#   '4yyg2J2uXOjCtCyT64984C',
#   '42bbDWZ8WmXTH7PkYAlGLu',
#   '3JXuMsnzwmqEEqQexK0q8b',
#   '2rh74erKixxVL5jybdahEd'],
#  'january 2018': ['4BERCV2vSwUKarF1UsD3nP',
#   '45w70aQhNwke1yrQZO0ffm',
#   '2xmrfQpmS2iJExTlklLoAL',
#   '6oNZ0WxqptE7V0qpjtyJ4a',
#   '7vGuf3Y35N4wmASOKLUVVU',
#   '0Zbbxnx4SGGHoIow4PpISP',
#   '7jZHUhAmW5oq1cq6s8IxmK',
#   '3sJHkcxojoJD2Ytbo1yLLF',
#   '2PuHj0tUOKud6fVKTZUXRO',
#   '5p6eKTYwFYitUS617IMtyd',
#   '3kxH7rqUBK8uYOyfIuWT7z',
#   '1RmPi2rBbY6pB97UDbsjeq',
#   '15ahYSiHAIMxAnujlXVtta',
#   '2Ro9FLIVhPwIQopSr48oJT',
#   '4LSkEJ5P5MV0y3PZqw7guJ',
#   '5AfJXFkWlmLBJhI23TNCIK',
#   '64fwanXDvwmsQrLsDSVHMv',
#   '1eyrmeiDpdTkOmA839nPVQ',
#   '4pWawf1Rq4qHDv4Ktqjg2D',
#   '5yFSF6qQA1rcLsQRnBsZgb',
#   '5AEtlRudpgdT5FtNiuly6Y',
#   '5uu28fUesZMl89lf9CLrgN',
#   '47165S9Ppynsd9rIzVG4uS',
#   '0q7oMII7kWTj1ZSX6GT6LU',
#   '1Bxzw8ag71snOU9IbhXVD6',
#   '0Ev562zA4pmUsBqjxsxxdx',
#   '4G3IXyVRxSx5lLhUvv3fu3',
#   '10hG4ZlpIUGvcZESL6Uhxx',
#   '5XiZK7m9PLppgIzJBpw2x5',
#   '7KT7VGnPU5QVXN3q1BOeqb',
#   '2DGa7iaidT5s0qnINlwMjJ',
#   '5ip3FCi89E2eDtId6kcJmo',
#   '7pstxLUhvsJC3M4TxHe2aI',
#   '2kLf4myxQME1Nd0voeKZri',
#   '1sfmIZRBmY5yq5wRQs987T',
#   '4DWSl33tt6k4H4Unj7YWs5',
#   '5xYVqJ7ppf4bTbbztvVOYx',
#   '0JiVRyTJcJnmlwCZ854K4p',
#   '7zTx8ePYAmPFQuxP3xlXZn',
#   '3kGfazcbVvVkuZunzlLgTD',
#   '37Qd6pycwS5oeiBEgpTgzc',
#   '7lYGmGag8kjKIhYt6Y65a8',
#   '42CeaId2XNlxugDvyqHfDf',
#   '75ZvA4QfFiZvzhj2xkaWAh',
#   '0OlnLZY4cmQzT6ZGttvWBM',
#   '0xJLLIqvDIgbe8LDqbSxrb',
#   '76rZUnOHbjsmCEJOLH0OKd',
#   '5Y4wLcnSQYycUHGmYDUrK0',
#   '5WggjuxMubr94bo33Aan4K',
#   '4xYzcWOLM685vCa5AkJXe9',
#   '5iPnsVuITetx7KctVo7RW9',
#   '2NNLAwAGqyDh3YNemWdcMj'],
#  'ending 2017': ['7a9wmrYMkvjS1eEGzQPaLp',
#   '5U1eDhGNl6uUQThJ4nBm7z',
#   '20OrSCxQNhfAtiWtbLn3hf',
#   '03t3IRKAyXPGeAWCidF03q',
#   '1OV5oUwrL4iw0UTfZy3pGe',
#   '3jteX7TMc7cPzIUCxHjqHe',
#   '5s6YL4Ym5xKtlOgmTICSat',
#   '77Y57qRJBvkGCUw9qs0qMg',
#   '6A9nyMBdNUzVcFHZUEZ71F',
#   '19cL3SOKpwnwoKkII7U3Wh',
#   '5kRPPEWFJIMox5qIkQkiz5',
#   '0Zbbxnx4SGGHoIow4PpISP',
#   '2CPqh63wRVscbceKcPxwvv',
#   '2OALaHcDdKkjYEpAr0Qzab',
#   '2btKtacOXuMtC9WjcNRvAA',
#   '5Z3GHaZ6ec9bsiI5BenrbY',
#   '5AEtlRudpgdT5FtNiuly6Y',
#   '7DsX5K72fewVGb47qj7Tbg',
#   '0tgVpDi06FyKpA1z0VMD4v',
#   '7EmGUiUaOSGDnUUQUDrOXC',
#   '7vGuf3Y35N4wmASOKLUVVU',
#   '577anBvdqX2NHWVLERO6wb',
#   '7D0t8BHJxakSnO6EVBglc4',
#   '7qs2GAglLWfxEfmO8u2u0A',
#   '6oNZ0WxqptE7V0qpjtyJ4a',
#   '1RmPi2rBbY6pB97UDbsjeq',
#   '57p8CBvPOxrvyCbn6ttl5r',
#   '7x6cBmHXwdS1EGwVx4silu',
#   '3sJHkcxojoJD2Ytbo1yLLF',
#   '5YtS0hAq1MQLjypNTzXPfC',
#   '2QCndYqRherBtKjBpyySC6',
#   '5yFSF6qQA1rcLsQRnBsZgb',
#   '15ahYSiHAIMxAnujlXVtta',
#   '1kcfGBb6kSrGqNIMW7rAlB',
#   '2elxgOyiNPM0QYjixON7cn',
#   '4THoSHxiabL1rd59iVWu2T',
#   '087OBLtoeS3Q6j0k6tMNAI',
#   '2Ro9FLIVhPwIQopSr48oJT',
#   '39jXnbACjiaiTwwhsr5sY5',
#   '7q0aQpiLv5tIsupcgQ3Ny4',
#   '7tmtOEDxPN7CWaQWBsG1DY',
#   '6liNJDyWJjyHAgDnAX95bw',
#   '4prEPl61C8qZpeo3IkYSMl',
#   '23oxJmDc1V9uLUSmN2LIvx',
#   '45HAjqRWiNv6mMPw4NvZrU',
#   '5LABCxgmP7DATATIJXOh6n',
#   '2prdNAY0rlnRSEer2WDBMs',
#   '0IcYIjsfFEOIY1GI4t7dLu',
#   '29jtZGdgpE2lWm2mkIt6HS',
#   '1UvpnDpXGTn5aGyAVDOCCw',
#   '1595LW73XBxkRk2ciQOHfr',
#   '184c1MtPKQENzNJd7fIh1t',
#   '7keXdrB4mz57u4b8YkCwag',
#   '5tVA6TkbaAH9QMITTQRrNv',
#   '5u64RlrnvvbtNh6R0EMh6o',
#   '2xmrfQpmS2iJExTlklLoAL',
#   '0MFDzxcs2Zk47nLq7ukC4S',
#   '2Za1AlJNvksouPPWbXpR2X',
#   '77dwRzKegOkVtlHajKnDCb',
#   '5b2QnYcT9rQIkhRWt4HztQ',
#   '4SoXQCrPQplashFebNaUw3',
#   '0OI7AFifLSoGzpb8bdBLLV',
#   '1ZyQGXH9dZ4AecevHhKUxi',
#   '2OY0rTp6WTvXXdqrv0EE0G',
#   '5VJ1eVOnlAlaA2mQcwmKC8',
#   '2MKXUXZIViCGpoFyysFpoj',
#   '3SktMqZmo3M9zbB7oKMIF7',
#   '6Vecwo7AHst9V2CE3kmwr0',
#   '1bhUWB0zJMIKr9yVPrkEuI',
#   '3VlbOrM6nYPprVvzBZllE5',
#   '64fwanXDvwmsQrLsDSVHMv',
#   '1OmcAT5Y8eg5bUPv9qJT4R',
#   '4LSkEJ5P5MV0y3PZqw7guJ',
#   '2IClzYyvgwrsmVVipYsx5T',
#   '5AfJXFkWlmLBJhI23TNCIK',
#   '4pWawf1Rq4qHDv4Ktqjg2D',
#   '6e65GRD6YTXUIK5xWWrYLA',
#   '34t13rSSZtr22CjcmroMmh',
#   '0pWUknNq4xoxybk4H3ypfK',
#   '4UErgRhgSCTfmSde2FEzsV',
#   '3Lfiu5sZ4M4B6JaKMBc0FU'],
#  'october 2017': ['20OrSCxQNhfAtiWtbLn3hf',
#   '03t3IRKAyXPGeAWCidF03q',
#   '6xNaObGQT8V8OM5OEm6p3G',
#   '3yWsWi2PAo9s6elIhnywIS',
#   '5UMD1Iz7yyVK8Q5FLsVt3q',
#   '0sbrF037ChAki4PUEd3fEC',
#   '7BESXRNE2SUFnAxX6Evqu6',
#   '6Z884oSfliz0mKqTJTXrwb',
#   '6WbADFqMvR8N5u0BvtsWQE',
#   '2OALaHcDdKkjYEpAr0Qzab',
#   '0Zbbxnx4SGGHoIow4PpISP',
#   '1wjzFQodRWrPcQ0AnYnvQ9',
#   '2kMKmb60xVUIWW2Out8ypz',
#   '2btKtacOXuMtC9WjcNRvAA',
#   '1qo2VV6AXTYwKk7NWGzSSA',
#   '3ySU5vwQB33iGulwcUL9qQ',
#   '7FqScuVJysPgwVFcepFJks',
#   '7oAraczbemGSNWqnbkU87R',
#   '7ARveOiD31w2Nq0n5FsSf8',
#   '2wXhdaTnmkkFSOidKfnOxA',
#   '7dOeiXeTSfA1ixaYmQcWu7',
#   '0CokSRCu5hZgPxcZBaEzVE',
#   '0B48113ZG9UfkWWt7qD9xX',
#   '4xlrALxuaCf9yZBHJeTSG6',
#   '3A7qX2QjDlPnazUsRk5y0M',
#   '2habSXqcJGExM6JJyskY7O',
#   '34oB5r0lcN3fYWCs2uA1k5',
#   '1p6bEgeBsRdsxl8HoRWYEB',
#   '5kRPPEWFJIMox5qIkQkiz5',
#   '4PKorFhOq9YfwOGJx0cOiJ',
#   '3Lfiu5sZ4M4B6JaKMBc0FU',
#   '3cfhXgklWpx5fCSYZOp9Wb',
#   '73NbHgUZ51H65Bfo2HFKUi',
#   '1AJQ97yAt6xfeF7nQaE1t8',
#   '7cQMJ0wDqVS5iM0JIvP6Ay',
#   '09oCOptpWAPyV0gqxBUCJr',
#   '72OGJT4cL9BQjHTa8h28tz',
#   '4I8u6xWJTAshUyJHiEprbz',
#   '6SznMYPQJHzr3IwsAHLId2',
#   '2pJZ1v8HezrAoZ0Fhzby92',
#   '25tbnjnjZjXIYrfgqGKxpG',
#   '2QWP8NYYplOqEFBYGCcq0S',
#   '5U1eDhGNl6uUQThJ4nBm7z',
#   '3jteX7TMc7cPzIUCxHjqHe']}
